# %%
import json

# %%
#load the store data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)

    return data

# %%
data = load_data("store_data.json")

# %%
#clean and structure the data
def clean_data(data):
    text_to_num = {"one": 1, "two": 2, "three": 3, "four": 4, "five": 5 }
    cleaned_data = []
    unique_users = set()
    for user in data:
        #clean rating
        raw_rating = str(user["rating"]).strip().lower()
        if raw_rating in text_to_num:
            raw_rating = text_to_num[raw_rating]
        user["rating"] = raw_rating
        #handke missing vals
        raw_age = user.get("age")
        if raw_age == None:
            user["age"] = None
        
        #deduplication
        if user["name"].strip() in unique_users:
            continue
        unique_users.add(user["name"])    
        cleaned_data.append(user)

    return cleaned_data

# %%
data = clean_data(data)

# %%
#meaningful insights
def get_insights(data):

    #avg rating
    tot_rating = 0
    poor_rating = 0
    for user in data:
        tot_rating += float(user["rating"])
        if float(user["rating"]) <= 3:
            poor_rating += 1
  
    
    avg_rating = tot_rating/len(data)
    print(f"avg rating = {avg_rating}")
    print(f"% of user with poor  rating = {poor_rating/len(data) * 100}%")

    #percentage of users with poor rating

# %%
#build recommendation feature
def get_recommendations(data):
    recommendations = []

    for user in data:
        curr_recomm = {}
        curr_recomm["name"] = user["name"]

        if float(user["rating"]) <= 4:
            curr_recomm["brand"] = "Apple"
        else:
            curr_recomm["brand"] = "Sumsung"
        recommendations.append(curr_recomm)
    return recommendations

# %%
get_recommendations(data)
# Out:
# [{'name': 'Alice', 'brand': 'Sumsung'},
#  {'name': 'Bob', 'brand': 'Apple'},
#  {'name': ' Charlie', 'brand': 'Apple'},
#  {'name': 'Diana', 'brand': 'Sumsung'},
#  {'name': 'Eve', 'brand': 'Apple'}]

# %%
print("hello jupyter lab i am in vs code")
# Out:
# hello jupyter lab i am in vs code

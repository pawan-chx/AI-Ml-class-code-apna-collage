# %%
k = 1
num = 4
j = num-1
c = 1
for i in range(num):
    str = "*"*k
    spc = " " * j
    print(spc + str, c )
    k += 2
    j -= 1
    c += 1
# Out:
#    * 1
#   *** 2
#  ***** 3
# ******* 4

# %%
arr = []

k = 1
num = 26
j = num-1
c = 1
for i in range(num):
    str = "*"*k
    spc = " "*j
    # cc = (((3*c)-2)/2)
    first = num/2+4

    # if c == first:
    #     s = int(((c*3)/6)-9)
    #     # h = int(c-s-1)
    #     pstr = "*"*(s)
    #     sc = ((c*2)-s)
    #     sp = " "*sc

    #     arr.append(spc + pstr + sp + pstr )

    if c > first:
        s = int(c/2-9)
        h = int(c-s-1)
        pstr_l = "*"*(s)
        pstr_r = "*"*(h)

        # print(spc + pstr_l + " " + pstr_r, c)
        arr.append(spc + pstr_l + " " + pstr_r )

    else:

        # print(spc + str, c) 
        arr.append(spc + str )

    k += 2
    j -= 1 
    c += 1   

for st in arr:
    print(st)
# Out:
#                          *
#                         ***
#                        *****
#                       *******
#                      *********
#                     ***********
#                    *************
#                   ***************
#                  *****************
#                 *******************
#                *********************
#               ***********************
#              *************************
#             ***************************
#            *****************************
#           *******************************
#          *********************************
#          *****************
#         ******************
#       * ******************
#      * *******************
#     ** *******************
#    ** ********************
#   *** ********************
#  *** *********************
# **** *********************

# %%
for st in arr:
    print(st)
# Out:
#                          *
#                         ***
#                        *****
#                       *******
#                      *********
#                     ***********
#                    *************
#                   ***************
#                  *****************
#                 *******************
#                *********************
#               ***********************
#              *************************
#             **** **********************
#            ***** ***********************
#           ****** ************************
#          ******* *************************
#         ******** **************************
#        ********* ***************************
#       ********** ****************************
#      *********** *****************************
#     ************ ******************************
#    ************* *******************************
#   ************** ********************************
# ...
